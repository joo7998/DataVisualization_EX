# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import platform
from matplotlib import font_manager, rc # Runtime Configuration
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')
    
import json 
from collections import Counter

# %%
df = pd.read_csv('bicycle6.csv', encoding='utf-8')
df
# Out:
#         Unnamed: 0        대여일자 대여시간(24) 대여소번호                          대여소명  \
# 0                0  2018-12-02       14  1366                1366. 일신초등학교 옆
# 1                2  2018-07-03       11   567              567.  성수역 2번출구 앞
# 2                3  2018-04-21       11  3102                  3102.  연희삼거리
# 3                4  2019-09-30       19   111               111. 상수역 2번출구 앞
# 4                5  2018-07-11       19  1021            1021.  강일동 리슈빌 빌딩앞
# ...            ...         ...      ...   ...                           ...
# 696355      701468  2020-03-02       18  1288                1288. 문정중교 사거리
# 696356      701469  2018-08-22        8   714          714.  한국SGI 양천문화회관 앞
# 696357      701470  2020-07-01       17  2621             2621. 한성백제역 2번 출구
# 696358      701471  2018-04-16       15   305                  305.  종로구청 옆
# 696359      701472  2018-07-29       17  1019  1019.  다성이즈빌아파트(호원대 대각선 맞은편)
#
#         대여권   연령대   성별 이동거리(km) 사용시간(hr) 속도(km/h)     년   월
# 0       정기권   30대    M     2.43     0.32     7.59  2018  12
# 1       정기권  70대~    M     3.73     0.72     5.18  2018   7
# 2       정기권   30대    M     3.01     0.28    10.75  2018   4
# 3       정기권   20대    M      1.7      0.2      8.5  2019   9
# 4       정기권   50대    M     2.69      0.3     8.97  2018   7
# ...     ...   ...  ...      ...      ...      ...   ...  ..
# 696355  일일권   30대    M    12.64     1.55     8.15  2020   3
# 696356  정기권   20대    F     1.38     0.17     8.12  2018   8
# 696357  정기권  70대~  NaN     1.07     0.27     3.96  2020   7
# 696358  정기권   40대    F     2.83      0.4     7.08  2018   4
# 696359  정기권   20대    F     1.21     0.13     9.31  2018   7
#
# [696360 rows x 13 columns]

# %%
del df['Unnamed: 0']
df.head()
# Out:
#          대여일자 대여시간(24) 대여소번호                대여소명  대여권   연령대 성별 이동거리(km)  \
# 0  2018-12-02       14  1366      1366. 일신초등학교 옆  정기권   30대  M     2.43
# 1  2018-07-03       11   567    567.  성수역 2번출구 앞  정기권  70대~  M     3.73
# 2  2018-04-21       11  3102        3102.  연희삼거리  정기권   30대  M     3.01
# 3  2019-09-30       19   111     111. 상수역 2번출구 앞  정기권   20대  M      1.7
# 4  2018-07-11       19  1021  1021.  강일동 리슈빌 빌딩앞  정기권   50대  M     2.69
#
#   사용시간(hr) 속도(km/h)     년   월
# 0     0.32     7.59  2018  12
# 1     0.72     5.18  2018   7
# 2     0.28    10.75  2018   4
# 3      0.2      8.5  2019   9
# 4      0.3     8.97  2018   7

# %%
age_counts = df['연령대'].value_counts()
age_counts
# Out:
# 20대     268992
# 30대     146680
# 40대      91522
# 정기권      72141
# 50대      50383
# ~10대     26134
# 일일권      24385
# 60대      12953
# 70대~      3170
# Name: 연령대, dtype: int64

# %%
sns.barplot(y=age_counts.index, x=age_counts.values)

# %%
# 연령대 별 이용량 - 년 별, 월 별

# %%
# df2 = df.pivot('대여시간(24)', '월', '연령대')
# df2

# %%
age_group = df.groupby('연령대')
age_group

# %%
age_group.groups

# %%
df['대여권'].value_counts()
# Out:
# 정기권    557013
# 일일권    139347
# Name: 대여권, dtype: int64

# %%
membership_group = df.groupby('대여권')
membership_group

# %%
membership_group.groups

# %%
sns.barplot(y=membership_type.index, x=membership_type.values)

# %%
df3 = pd.merge(age, membership, left_index=True, right_index=True, how='left')
df3

# %%
plt.figure(figsize=(6,6))

plt.scatter(df2['연령대'], df2['대여권'], s=50)

plt.xlabel('연령대')
plt.ylabel('대여권') 
plt.grid()
plt.show()
